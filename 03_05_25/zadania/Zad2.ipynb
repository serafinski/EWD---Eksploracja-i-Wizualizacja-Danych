# %% [markdown]
# ### Zadanie 2
# Wczytaj zbiory w plikach `life_expectancy_years.csv` i `housing.csv`. Eksploruj je za pomocą poznanych metod. Zanotuj swoje obserwacje.

# %%
import pandas as pd

# %%
df = pd.read_csv("life_expectancy_years.csv")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 302 entries, country to 2100
# dtypes: float64(301), object(1)
# memory usage: 460.2+ KB
#              1800        1801        1802        1803        1804        1805  \
# count  186.000000  186.000000  186.000000  186.000000  186.000000  186.000000
# mean    31.503763   31.463441   31.480108   31.385484   31.460753   31.586559
# std      3.809510    3.801217    3.932344    3.955872    3.928388    4.003874
# min     23.400000   23.400000   23.400000   19.600000   23.400000   23.400000
# 25%     29.025000   28.925000   28.900000   28.900000   28.925000   29.025000
# 50%     31.750000   31.650000   31.550000   31.500000   31.550000   31.650000
# 75%     33.875000   33.900000   33.875000   33.675000   33.775000   33.875000
# max     42.900000   40.300000   44.400000   44.800000   42.800000   44.300000
#
#              1806        1807        1808        1809  ...        2091  \
# ...

# %%
# Wypisz wszystkie kolumny
df.columns
df["2100"]
# Out:
# 0      76.8
# 1      80.0
# 2      88.4
# 3       NaN
# 4      83.3
#        ...
# 190    80.8
# 191    78.0
# 192    77.7
# 193    77.1
# 194    74.4
# Name: 2100, Length: 195, dtype: float64

# %%
# Wypisz wszytkie wiersze z NaN
df[df.isnull().any(axis=1)]
# Usun wiersze z NaN
df.dropna(inplace=True)
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1
# 1                  Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2                 Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 4    United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
# 5               Argentina  33.2  33.2  33.2  33.2  33.2  33.2  33.2  33.2
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190                 Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4
# 191                 Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4
# 192          South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5
# 193                Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6
# 194              Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7
#
#      1808  ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# ...

# %%
df[df.country == "Poland"]
# Out:
#     country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2091  \
# 140  Poland  35.9  35.9  35.9  35.9  35.9  35.9  35.9  35.9  35.9  ...  87.3
#
#      2092  2093  2094  2095  2096  2097  2098  2099  2100
# 140  87.5  87.6  87.7  87.8  87.9  88.0  88.1  88.2  88.3
#
# [1 rows x 302 columns]

# %%
# Znajdź kraj z największą oczekiwaną długością życia w 2100 roku
df[df["2100"] == df["2100"].max()]
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 152  Singapore  29.1  29.1  29.1  29.1  29.1  29.1  29.1  29.1  29.1  ...
#
#      2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 152  93.4  93.5  93.6  93.7  93.8  94.0  94.1  94.2  94.3  94.4
#
# [1 rows x 302 columns]

# %%
# Wypisz średnią oczekiwaną długość życia w 2100 roku
df["2100"].mean()
# Out:
# np.float64(84.43064516129031)
