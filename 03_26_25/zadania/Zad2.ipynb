# %% [markdown]
# Wczytaj plik `waw_weather_monthly.csv`, a następnie:
# * Stwórz wykres słupkowy (`plt.bar()`) przedstawiający amplitudę średnich temperatur w każdym miesiącu (Tmax - Tmin).
# * Stwórz podobny wykres, tak aby podstawą słupków była temperatura minimalna (sprawdź w [dokumentacji](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html), jak to zrobić). Ustaw odpowiedni zakres osi y (`plt.ylim()`)
# * Pamiętaj o dodaniu odpowiednich opisów osi i tytułów. Aby nazwy miesięcy były czytelne, należy je obrócić (np. `plt.xticks(rotation=90)`).
# * Opcjonalnie: Dodaj anotacje (`plt.annotate()`) z minimalną i maksymalną wartością temperatury pod i nad każdym słupkiem.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../data/waw_weather_monthly.csv", parse_dates=True, index_col="time")
df.head()
# Out:
# /var/folders/dh/n09r5skj4tv2v3zp6v8qj3qr0000gn/T/ipykernel_32275/3353337236.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("../data/waw_weather_monthly.csv", parse_dates=True, index_col="time")
#           temperature_2m_max  temperature_2m_min  apparent_temperature_max  \
# time
# January                 2.53               -1.46                     -2.08
# February                5.79                0.23                      1.25
# March                   7.36               -1.94                      3.36
# April                  10.39                2.35                      6.97
# May                    18.42                8.79                     16.03
#
#           apparent_temperature_min  precipitation_sum  windspeed_10m_max
# time
# January                      -6.49               2.17              22.97
# February                     -4.45               2.26              23.91
# March                        -6.14               0.14              14.35
# April                        -1.38               2.12              16.93
# May                           5.85               2.17              19.57

# %%
# Tmax - Tmin
plt.xticks(rotation=90)
plt.bar(df.index, df["temperature_2m_max"] - df["temperature_2m_min"])
# Out:
# <BarContainer object of 12 artists>

# %%
plt.xticks(rotation=90)
plt.bar(df.index, df["temperature_2m_max"] - df["temperature_2m_min"], bottom=df["temperature_2m_min"])
plt.ylim(min(df["temperature_2m_min"]-5), max(df["temperature_2m_max"]+5))

for i in range(len(df.index)):
    plt.annotate(f"{df['temperature_2m_min'][i]:.1f}°C", 
                 xy=(i, df['temperature_2m_min'][i] - 0.8),  
                 ha='center',
                 fontsize=9)
    
    plt.annotate(f"{df['temperature_2m_max'][i]:.1f}°C", 
                 xy=(i, df['temperature_2m_max'][i] + 0.3),  
                 ha='center',
                 fontsize=9)
# Out:
# /var/folders/dh/n09r5skj4tv2v3zp6v8qj3qr0000gn/T/ipykernel_32275/1319116288.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(f"{df['temperature_2m_min'][i]:.1f}°C",
# /var/folders/dh/n09r5skj4tv2v3zp6v8qj3qr0000gn/T/ipykernel_32275/1319116288.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xy=(i, df['temperature_2m_min'][i] - 0.8),
# /var/folders/dh/n09r5skj4tv2v3zp6v8qj3qr0000gn/T/ipykernel_32275/1319116288.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(f"{df['temperature_2m_max'][i]:.1f}°C",
# /var/folders/dh/n09r5skj4tv2v3zp6v8qj3qr0000gn/T/ipykernel_32275/1319116288.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xy=(i, df['temperature_2m_max'][i] + 0.3),
